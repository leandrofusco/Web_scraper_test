# %% [markdown]
# # Functions to weg scraper

# %%
import requests # para fazer requisição a pagina
from bs4 import BeautifulSoup # pra fazer o parser do código html
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from pprint import pprint
import pandas as pd
import csv

# %%
#Recupera uma lista de todos os links internos encontrados em uma página
def getInternalLinks(bsObj, includeUrl):
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
    return internalLinks

# %%
searchterm = 'celular'

# function to get data
def get_page(url):
    response = requests.get(url)
    if not response.ok:
        print('server responded:', response.status_code)
    else:    
        soup = BeautifulSoup(response.content, 'html.parser')
        
    return soup

# function to get several details data
def get_detail_data(soup):
    try:
        title = soup.find('h1', class_='ui-pdp-title').text.stri
    except:
        title = ''
    try:
        price = soup.find_all('span', class_='price-tag-fraction')[1].text # 
    except:            
        price = ''
    data = {
        'title': title,
        'price': price
    }
    return data

# function to get links
def get_index_data(soup):
    try:
        links = soup.find_all('a', class_='ui-search-item__group__element ui-search-link')
    except:
        links = []
    
    urls = [item.get('href') for item in links]
       
    return urls   


 # Main function   
def main():
    url = 'https://lista.mercadolivre.com.br/celular#D[A:{searchterm}]'
    
    products = get_index_data(get_page(url))
    
    for link in products:
        data = get_detail_data(get_page(link))
        write_csv(data,link)
        
        
# function to save data    
def write_csv(data, url):
    with open('output.csv', 'a') as csvfile:
        writer = csv.writer(csvfile)
        
        row= [data['title'] ,data['price'], url]
        
        writer.writerow(row)

        
if __name__ == '__main__':
    main()

# %%
searchterm = 'celular'

# function to get data
def get_page(url):
    response = requests.get(url)
    if not response.ok:
        print('server responded:', response.status_code)
    else:    
        soup = BeautifulSoup(response.content, 'html.parser')
    return soup

# function to get several details data
def get_detail_data(soup):
    try:
        title = soup.find('h1', class_='ui-pdp-title').text
    except:
        title = ''
    try:
        price = soup.find('div', class_='andes-tooltip__trigger').find('span', class_='price-tag-fraction').text
    except:            
        price = ''
    data = {
        'title': title,
        'price': price
    }
    return data

def get_index_data(soup):
    try:
        links = soup.find_all('a', class_='ui-search-item__group__element ui-search-link')
    except:
        links = []
    
    urls = [item.get('href') for item in links]
    print(len(urls))    
    return urls   


    
def main():
    url = 'https://lista.mercadolivre.com.br/celular#D[A:{searchterm}]'
    
    products = get_index_data(get_page(url))
    
    for link in products:
        data = get_detail_data(get_page(link))
        print(data)
# function to save data    
# def write_csv(data):
#     with open('output.csv', 'a') as csvfile:
#         writer = csv.writer(csvfile)
        
#         writer.writerow()



# def parse(soup):
#     result = soup.find_all('div', {'class':'ui-search-result__content-wrapper'})
    
        
if __name__ == '__main__':
    main()
# Out:
# 51
# {'title': 'iPhone 11 128 GB Preto', 'price': '5.506'}
# {'title': 'Samsung Galaxy S20+ Dual SIM 128 GB  cloud blue 8 GB RAM', 'price': '3.789'}
# {'title': 'Samsung Galaxy M21s Dual SIM 64 GB  azul 4 GB RAM', 'price': '1.699'}
# {'title': 'Asus ZenFone Max Shot ZB634KL Dual SIM 64 GB  vermelho 4 GB RAM', 'price': '999'}
# {'title': 'LG K22 Dual SIM 32 GB  red 2 GB RAM', 'price': '901'}
# {'title': 'Samsung Galaxy A01 Core Dual SIM 32 GB  vermelho 2 GB RAM', 'price': '999'}
# {'title': 'Xiaomi Redmi Note 8 Dual SIM 64 GB neptune blue 4 GB RAM', 'price': '1.267'}
# {'title': 'Smartphone Samsung Galaxy S10 Tela De 6.1 128gb 8gb Ram', 'price': '4.699'}
# {'title': 'Obasmart 3 Obabox O Novo Smartphone Para A 3º Idade Original', 'price': '997'}
# {'title': 'LG K22+ Dual SIM 64 GB  titan 3 GB RAM', 'price': '1.000'}
# {'title': 'Samsung Galaxy A21s Dual SIM 64 GB preto 4 GB RAM', 'price': '1.430'}
# {'title': 'LG K41S Dual SIM 32 GB  titânio 3 GB RAM', 'price': '1.099'}
# {'title': 'Samsung Galaxy A31 Dual SIM 128 GB  prism crush black 4 GB RAM', 'price': '1.509'}
# {'title': 'Samsung Galaxy A01 Dual SIM 32 GB  vermelho 2 GB RAM', 'price': '685'}
# {'title': 'Samsung Galaxy A10s Dual SIM 32 GB  azul 2 GB RAM', 'price': '838'}
# {'title': 'Moto G9 Play Dual SIM 64 GB  azul-safira 4 GB RAM', 'price': '1.623'}
# {'title': 'Samsung Galaxy M31 Dual SIM 128 GB  preto 6 GB RAM', 'price': '1.999'}
# {'title': 'Xiaomi Redmi Note 9S Dual SIM 128 GB cinza 6 GB RAM', 'price': '1.794'}
# {'title': 'Xiaomi Redmi 9 (Global) Dual SIM 64 GB carbon grey 4 GB RAM', 'price': '1.120'}
# {'title': 'LG K52 (13 Mpx) Dual SIM 64 GB  gray 3 GB RAM', 'price': '1.399'}
# {'title': 'LG K51S Dual SIM 64 GB  titan 3 GB RAM', 'price': '1.299'}
# {'title': 'Asus ZenFone Max Shot ZB634KL Dual SIM 32 GB  vermelho 3 GB RAM', 'price': '949'}
# {'title': 'Multilaser Flip Vita Dual SIM 32 MB  vermelho 32 MB RAM', 'price': '164'}
# {'title': 'Moto G8 Power Lite Dual SIM 64 GB aqua 4 GB RAM', 'price': '1.199'}
# {'title': 'Samsung Galaxy A11 Dual SIM 64 GB  vermelho 3 GB RAM', 'price': '1.299'}
# {'title': 'Xiaomi Poco X3 NFC Dual SIM 128 GB cobalt blue 6 GB RAM', 'price': '1.940'}
# {'title': 'Xiaomi Redmi Note 9 Dual SIM 128 GB  cinza-meia-noite 4 GB RAM', 'price': '1.448'}
# {'title': 'LG K61 Dual SIM 128 GB  branco 4 GB RAM', 'price': '1.289'}
# {'title': 'Xiaomi Redmi Note 9 Pro (64 Mpx) Dual SIM 128 GB  verde-tropical 6 GB RAM', 'price': '2.005'}
# {'title': 'LG B220 Dual SIM 32 MB  preto 32 MB RAM', 'price': '117'}
# {'title': 'Multilaser E Lite Dual SIM 32 GB  preto 512 MB RAM', 'price': '399'}
# {'title': 'Multilaser Zapp Dual SIM 512 MB  preto 256 MB RAM', 'price': '219'}
# {'title': 'Xiaomi Redmi Note 8 Dual SIM 128 GB space black 4 GB RAM', 'price': '1.496'}
# {'title': 'Multilaser Up Play Dual SIM 32 MB  preto 32 MB RAM', 'price': '100'}
# {'title': 'Multilaser Vita Dual SIM 32 MB  preto 24 MB RAM', 'price': '115'}
# {'title': 'Xiaomi Redmi 9A Dual SIM 32 GB  verde 2 GB RAM', 'price': '809'}
# {'title': 'Samsung Galaxy A51 Dual SIM 128 GB  prism crush black 4 GB RAM', 'price': '2.499'}
# {'title': 'Multilaser F Dual SIM 32 GB  café 1 GB RAM', 'price': '499'}
# {'title': 'Xiaomi Redmi Note 8 Pro Dual SIM 128 GB  verde-floresta 6 GB RAM', 'price': '1.678'}
# {'title': 'Samsung Galaxy A71 Dual SIM 128 GB  preto 6 GB RAM', 'price': '2.968'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-80f3406b583d> in <module>
#      60
#      61 if __name__ == '__main__':
# ---> 62     main()
#
# <ipython-input-48-80f3406b583d> in main()
#      44
#      45     for link in products:
# ---> 46         data = get_detail_data(get_page(link))
#      47         print(data)
#      48 # function to save data
#
# <ipython-input-48-80f3406b583d> in get_page(url)
#       3 # function to get data
#       4 def get_page(url):
# ----> 5     response = requests.get(url)
#       6     if not response.ok:
#       7         print('server responded:', response.status_code)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
url='https://lista.mercadolivre.com.br/celular#D[A:celular]'

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
blocos = soup.find_all('div', class_='ui-search-result__content-wrapper')

# %%
PATH = "D:/chromedriver2/chromedriver.exe"

option = Options()
option.headless=True

driver = webdriver.Chrome(PATH, options=option)
driver.get("https://lista.mercadolivre.com.br/celular#D[A:celular]")

# %%
link = driver.find_element_by_link_text("Seguinte")
print(link.text)
# Out:
# Seguinte

# %%
link = driver

for bloco in blocos:
    name = bloco.find('h2').text
    print(name)
    
    valor = bloco.find('span', class_='price-tag-fraction').text
    print(valor)
    print('=======================')

print(len(name))
# Out:
# Xiaomi Redmi Note 9S Dual SIM 128 GB azul 4 GB RAM
# 1.728
# =======================
# Xiaomi Poco X3 NFC Dual SIM 128 GB cobalt blue 6 GB RAM
# 1.899
# =======================
# Samsung Galaxy A31 Dual SIM 128 GB prism crush black 4 GB RAM
# 1.499
# =======================
# Xiaomi Redmi Note 8 Dual SIM 64 GB neptune blue 4 GB RAM
# 1.249
# =======================
# iPhone 11 64 GB Branco
# 4.439
# =======================
# Xiaomi Redmi Note 9 Dual SIM 128 GB cinza-meia-noite 4 GB RAM
# 1.438
# =======================
# Xiaomi Redmi 9A Dual SIM 32 GB azul 2 GB RAM
# 813
# =======================
# Obasmart 3 Obabox O Novo Smartphone Para A 3º Idade Original
# 997
# =======================
# Celular Para Idosos Com Botão Sos Teclas Grandes
# 127
# =======================
# Asus ZenFone Max Shot ZB634KL Dual SIM 64 GB vermelho 4 GB RAM
# 1.099
# =======================
# Xiaomi Redmi Note 9 Pro (64 Mpx) Dual SIM 128 GB verde-tropical 6 GB RAM
# 2.005
# =======================
# Xiaomi Redmi Note 8 Pro Dual SIM 128 GB verde-floresta 6 GB RAM
# 1.678
# =======================
# Samsung Galaxy A21s Dual SIM 64 GB preto 4 GB RAM
# 1.410
# =======================
# Samsung Galaxy A01 Core Dual SIM 32 GB preto 2 GB RAM
# 799
# =======================
# Samsung Galaxy A10s Dual SIM 32 GB azul 2 GB RAM
# 1.099
# =======================
